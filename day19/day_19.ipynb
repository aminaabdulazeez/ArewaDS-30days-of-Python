# %% [markdown]
# # Day19 Assignment

# %% [markdown]
# ## Excercise: Level1

# %%
#Read obama_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = './obama_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 66
# Number of words: 2400

# %%
#Read obama_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = './michelle_obama_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 83
# Number of words: 2204

# %%
#Read donald_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = './donald_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 48
# Number of words: 1259

# %%
#Read melina_trump_speech.txt file and count number of lines and words
def count_lines_and_words(filename):
    line_count = 0
    word_count = 0

    with open(filename, 'r') as file:
        for line in file:
            line_count += 1
            words = line.split()
            word_count += len(words)

    return line_count, word_count

filename = './melina_trump_speech.txt'
lines, words = count_lines_and_words(filename)

print("Number of lines:", lines)
print("Number of words:", words)
# Out:
# Number of lines: 33
# Number of words: 1375

# %%
# Read the countries_data.json, create a function that finds the ten most spoken languages

import json

def find_most_spoken_languages():
    with open('./countries_data.json', 'r', encoding='utf-8') as file:
        data = json.load(file)

    language_count = {}

    for country in data:
        languages = country['languages']

        for language in languages:
            if language in language_count:
                language_count[language] += 1
            else:
                language_count[language] = 1

    sorted_languages = sorted(language_count.items(), key=lambda x: x[1], reverse=True)
    most_spoken_languages = [language for language, count in sorted_languages[:10]]

    return most_spoken_languages

most_spoken = find_most_spoken_languages()
print("Ten most spoken languages:")
for language in most_spoken:
    print(language)
# Out:
# Ten most spoken languages:
# English
# French
# Arabic
# Spanish
# Portuguese
# Russian
# Dutch
# German
# Chinese
# Serbian

# %% [markdown]
# ## Excercise:Level2

# %%
#Extract all incoming email addresses as a list from the email_exchange_big.txt file.
import re

def extract_incoming_email_addresses(filename):
    email_addresses = []

    with open(filename, 'r') as file:
        for line in file:
            if line.startswith("From:"):
                match = re.search(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b', line)
                if match:
                    email_addresses.append(match.group())

    return email_addresses

filename = './email_exchange_big.txt'
addresses = extract_incoming_email_addresses(filename)

print("Incoming email addresses:")
for address in addresses:
    print(address)
# Out:
# Incoming email addresses:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# david.horwitz@uct.ac.za
# ian@caret.cam.ac.uk
# aaronz@vt.edu
# aaronz@vt.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# ian@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# ian@caret.cam.ac.uk
# david.horwitz@uct.ac.za
# gopal.ramasammycook@gmail.com
# antranig@caret.cam.ac.uk
# arwhyte@umich.edu
# arwhyte@umich.edu
# arwhyte@umich.edu
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# ray@media.berkeley.edu
# ktsao@stanford.edu
# sgithens@caret.cam.ac.uk
# zqian@umich.edu
# cwen@iupui.edu
# antranig@caret.cam.ac.uk
# zqian@umich.edu
# jimeng@umich.edu
# jimeng@umich.edu
# antranig@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# ssmail@indiana.edu
# ian@caret.cam.ac.uk
# ian@caret.cam.ac.uk
# zqian@umich.edu

# %%
# Use the function, find_most_frequent_words to find ten most frequent words used in Obama's speech
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = './obama_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)
# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(frequency , word)
# Out:
# 129 the
# 113 and
# 81 of
# 70 to
# 67 our
# 62 we
# 50 that
# 48 a
# 36 is
# 25 in

# %%
# Use the function, find_most_frequent_words to find ten most frequent words used in michelle's speech
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = './michelle_obama_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)
# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(frequency , word)
# Out:
# 96 and
# 85 the
# 84 to
# 50 that
# 46 of
# 42 â
# 41 a
# 37 he
# 36 in
# 28 my

# %%
# Use the function, find_most_frequent_words to find ten most frequent words used in trumphs speech
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = './donald_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)
# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(frequency , word)
# Out:
# 65 the
# 59 and
# 43 we
# 40 will
# 38 of
# 32 to
# 30 our
# 20 is
# 16 america
# 14 â

# %%
# Use the function, find_most_frequent_words to find ten most frequent words used in Obama's speech
import re
from collections import Counter

def find_most_common_words(data, num_words):
    words = re.findall(r'\b\w+\b', data.lower())
    word_counter = Counter(words)
    common_words = [(word, freq) for word, freq in word_counter.items()]
    common_words.sort(key=lambda x: x[1], reverse=True)
    return common_words[:num_words]

# Read Obama's speech from the file
filename = './melina_trump_speech.txt'
with open(filename, 'r') as file:
    speech_text = file.read()

# Find ten most frequent words in Obama's speech
most_frequent_words = find_most_common_words(speech_text, 10)
# Print the ten most frequent words
for word, frequency in most_frequent_words:
    print(frequency , word)
# Out:
# 77 and
# 55 to
# 52 the
# 29 is
# 28 i
# 27 for
# 25 of
# 24 that
# 22 a
# 21 you

# %%
#10 most repeated words in the romeo_and_juliet.txt
import re
from collections import Counter

# Read the content of the file
with open('./romeo_and_juliet.txt', 'r') as file:
    content = file.read()

# Remove punctuation and convert to lowercase
content = re.sub(r'[^\w\s]', '', content.lower())

# Split the content into words
words = content.split()

# Count the occurrences of each word
word_counts = Counter(words)
# Get the 10 most common words and their frequencies
top_10_words = word_counts.most_common(10)

# Print the results
print("The 10 most repeated words in 'romeo_and_juliet.txt' are:")
for word, count in top_10_words:
    print(f"{word}: {count}")
# Out:
# The 10 most repeated words in 'romeo_and_juliet.txt' are:
# the: 866
# and: 793
# to: 625
# i: 585
# of: 535
# a: 527
# in: 377
# is: 375
# that: 363
# you: 362

# %%
#Count the number of lines containing python or Python in hacker_news.csv
import csv

file_path = "./hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) > 2 and "python" in row[2].lower():
            count += 1

print("Number of lines containing 'python' or 'Python':", count)
# Out:
# Number of lines containing 'python' or 'Python': 101

# %%
#Count the number lines containing JavaScript, javascript or Javascript
import csv

file_path = "./hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        try:
            if len(row) > 2 and ("JavaScript" in row[2] or "javascript" in row[2] or "Javascript" in row[2]):
                count += 1
        except IndexError:
            pass
print("Number of lines containing 'JavaScript', 'javascript', or 'Javascript':", count)
# Out:
# Number of lines containing 'JavaScript', 'javascript', or 'Javascript': 70

# %%
# Count the number lines containing Java and not JavaScript in hacker_news.csv
import csv

file_path = "./hacker_news.csv"

count = 0

with open(file_path, "r", encoding="utf-8") as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if len(row) > 2 and "Java" in row[2] and "JavaScript" not in row[2]:
            count += 1

print("Number of lines containing 'Java' but not 'JavaScript':", count)
# Out:
# Number of lines containing 'Java' but not 'JavaScript': 2
